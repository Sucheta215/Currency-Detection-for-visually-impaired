# %%
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open(r"newcurr\testing\10\20.jpg")
img.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open(r"newcurr\testing\10\20.jpg")
plt.imshow(img)

# %%
newsize = (1300,1000)
ni = img.resize(newsize)
plt.imshow(ni)

# %%
# top-left  bottom-right
part = (239,200,1200,800)
ci = ni.crop(part)
plt.imshow(ci)

# %%
ci = ci.save(r"newcurr\exp\suchuu_and_srishti_are_bffs_foreverrrrrrrrrrrr.jpg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f0306e0711a8> in <module>
# ----> 1 ci = ci.save(r"newcurr\exp\suchuu_and_srishti_are_bffs_foreverrrrrrrrrrrr.jpg")
#
# AttributeError: 'NoneType' object has no attribute 'save'

# %%
v = 4
path = fr"newcurr\training\10\{v}.jpg"
i = Image.open(path)
plt.imshow(i)

# %%
v = 1
newsize = (1300,1000) #for resizing
part = (239,200,1200,800) #for cropping
while (v<=92):
    path = fr"newcurr\training\20\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\training\20\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
print("Abhi pawwwry karte hai!!!")
# Out:
# Abhi pawwwry karte hai!!!

# %%
import time
start = time.time()
time.sleep(1)
v = 1
newsize = (1300,1000)
part = (239,200,1200,800)
while (v<=108):
    path = fr"newcurr\training\10\{v}.jpg" # image modificatrions for Rs.10 notes
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\training\10\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v=1
while (v<=97):
    path = fr"newcurr\training\20\{v}.jpg"  # image modificatrions for Rs.20 notes
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\training\20\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=102):
    path = fr"newcurr\training\50\{v}.jpg"  # image modificatrions for Rs.50 notes
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\training\50\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=113):
    path = fr"newcurr\training\100\{v}.jpg"  # image modificatrions for Rs.100 notes
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\training\100\{v}.jpg" 
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=106):
    path = fr"newcurr\training\200\{v}.jpg"  # image modificatrions for Rs.200 notes
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\training\200\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=106):
    path = fr"newcurr\training\500\{v}.jpg"  # image modificatrions for Rs.500 notes
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\training\500\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=105):
    path = fr"newcurr\training\2000\{v}.jpg"  # image modificatrions for Rs.2000 notes
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\training\2000\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
print("Abhi pawwwry karte hai!!!")
end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-9ba0ddca131f> in <module>
#       7 while (v<=108):
#       8     path = fr"newcurr\training\10\{v}.jpg" # image modificatrions for Rs.10 notes
# ----> 9     img = Image.open(path)
#      10     ni = img.resize(newsize)
#      11     ci = ni.crop(part)
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2889
#    2890     if filename:
# -> 2891         fp = builtins.open(filename, "rb")
#    2892         exclusive_fp = True
#    2893
#
# FileNotFoundError: [Errno 2] No such file or directory: 'newcurr\\training\\10\\52.jpg'

# %%
import time
from PIL import Image
start = time.time()
time.sleep(1)
v = 1
newsize = (1300,1000)
part = (239,200,1200,800)
while (v<=20):
    path = fr"curr\validation\10\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\validation\10\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v=1
while (v<=27):
    path = fr"curr\validation\20\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\validation\20\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=22):
    path = fr"curr\validation\50\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\validation\50\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=24):
    path = fr"curr\validation\100\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\validation\100\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=18):
    path = fr"curr\validation\200\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\validation\200\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=20):
    path = fr"curr\validation\500\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\validation\500\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=25):
    path = fr"curr\validation\2000\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\validation\2000\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
print("Done")
end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# Done
# Runtime of the program is 9.193032026290894

# %%
import time
from PIL import Image
start = time.time()
time.sleep(1)
v = 1
newsize = (1300,1000)
part = (239,200,1200,800)
while (v<=28):
    path = fr"newcurr\testing\10\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\testing\10\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v=1
while (v<=28):
    path = fr"newcurr\testing\20\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\testing\20\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=30):
    path = fr"newcurr\testing\50\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\testing\50\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=30):
    path = fr"newcurr\testing\100\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\testing\100\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=27):
    path = fr"newcurr\testing\200\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\testing\200\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=29):
    path = fr"newcurr\testing\500\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\testing\500\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
v = 1
while (v<=29):
    path = fr"newcurr\testing\2000\{v}.jpg"
    img = Image.open(path)
    ni = img.resize(newsize)
    ci = ni.crop(part)
    new_path = fr"newcurr\testing\2000\{v}.jpg"
    ci = ci.save(new_path)
    v = v + 1
print("Done")
end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# Done
# Runtime of the program is 9.092931509017944

# %%
# t = 67.77577
# m = int(t//60)
# s = int(t%60)
# print(f"Time: {m} min {s}sec")
